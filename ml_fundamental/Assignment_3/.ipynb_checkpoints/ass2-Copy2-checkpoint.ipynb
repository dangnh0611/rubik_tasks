# %%
import numpy as np 
import os
import sys
import cv2
import matplotlib.pyplot as plt
import skimage
import random
from sklearn import model_selection

# %% [markdown]
# Function return the closet cluster centroid to each sample in data

# %%
def findClosetCentroids(data,centroids):
    """Return the closet centroid index to each data point"""
    nSample=data.shape[0]
    #number of clusters
    K=centroids.shape[0]
    index=np.zeros((nSample,1))
    temp=np.zeros((K,1))
    for i in range(nSample):
        for j in range(K):
            temp[j]=np.sum((data[i,:]-centroids[j,:])**2)
            index[i]=np.argmin(temp)
    return index

# %% [markdown]
# Function to update the cluster's centroid base on the mean of members in each cluster

# %%
def updateCentroids(data,index,K):
    """Update the centroids"""
    temp=np.zeros((K,data.shape[1]))
    count=np.zeros((K,1))
    for i in range(index.shape[0]):
        temp[int(index[i])]+=data[i]
        count[int(index[i])]+=1
    centroids=temp/count
    return centroids,count

# %% [markdown]
# Initialize centroids list randomlly, each one is picked in the data sample

# %%
def randomInitCentroids(data,K):
    print(data.shape)
    centroids=np.zeros((K,data.shape[1]))
    for i in range(K):
        centroids[i]=data[np.random.randint(0,data.shape[0]+1)]
    return centroids

# %% [markdown]
# Implement K-mean clustering algorithm

# %%
def KmeanClustering(data,K,epoch=500):
    """K-mean clustering implementation"""
    centroids=randomInitCentroids(data,K)
    for i in range(epoch):
        index=findClosetCentroids(data,centroids)
        centroids,count=updateCentroids(data,index,centroids.shape[0])
    return centroids,count

# %% [markdown]
# Logistic regression implementation

# %%
class LogisticRegression:
    def __init__(self, threshold=0.5):
        self.threshold = threshold
        
    def predict(self, x):
        z = np.sum(x@self.W, axis=1)
        return 1 / (1 + np.exp(-z))
    
    #fit Weight by a batch
    def learn(self, x, y, learning_rate):
        y_hat = self.predict(x).reshape((30,1))
        dif=y-y_hat
        new_W = x.T@dif
        self.W = self.W + learning_rate * new_W
        
    def evaluate(self, x, y):
        y_pred = self.predict(x).reshape(y.shape)
        return {
            "loss": -np.mean(y * np.log(y_pred) + (1 - y) * np.log(1 - y_pred)),
            "accuracy": np.sum((y_pred > self.threshold).astype(int) == y) / y.shape[0]
        }
    
    def fit(
        self, x, y, x_valid = None, y_valid = None,
        learning_rate = 0.001,
        learning_rate_decay = 1,
        batch_size = 32,
        epoch = 1,
        verbose = False
    ):
        self.W = np.random.rand(x.shape[1],1)
        if x_valid is None:
            x_valid = x
        if y_valid is None:
            y_valid = y
        step = x.shape[0] // batch_size + (x.shape[0] % batch_size != 0)
        metric_graph = {
            "loss": [],
            "accuracy": []
        }
        for e in range(epoch):
            for i in range(step):
                self.learn(
                    x[batch_size * i : batch_size * (i + 1),],
                    y[batch_size * i : batch_size * (i + 1),],
                    learning_rate
                )
                metrics = self.evaluate(x_valid, y_valid)
                if (e <= 5 or (i + 1) == step) and verbose:
                    metrics = self.evaluate(x_valid, y_valid)
                    print("Epoch %d Step %d: Loss %f, Acc %f" % (e + 1, i + 1, metrics["loss"], metrics["accuracy"]))
            
            metrics = self.evaluate(x_valid, y_valid)
            metric_graph["loss"].append(metrics["loss"])
            metric_graph["accuracy"].append(metrics["accuracy"])
            learning_rate *= learning_rate_decay
        
        plt.plot(metric_graph["loss"])
        plt.title("Loss")
        plt.show()
        plt.title("Accuracy")
        plt.plot(metric_graph["accuracy"])
        plt.show()

# %% [markdown]
# Feature extraction using K-mean clustering
# Finding the most dominant color, sort by frequency, and then flatten

# %%
K=3
nIterations=20

country_filename=[os.path.join("country",name) for name in os.listdir("country")]
metro_filename=[os.path.join("metro",name) for name in os.listdir("metro")]
X=np.zeros((len(country_filename)+len(metro_filename),3*K))
y=np.zeros((len(country_filename)+len(metro_filename),1))

for idx,filename in enumerate(country_filename+metro_filename):
    img=skimage.io.imread(filename)
    img=skimage.transform.resize(img,(300,400,3))
    data=img.reshape(-1,3)
    centroids,count=KmeanClustering(data,K,nIterations)
    centroids_dict={count[i,0]:centroids[i,:] for i in range(K)}
    #sorted by color frequency
    sorted_count=sorted(centroids_dict,reverse=True)
    sorted_centroids=[centroids_dict[i] for i in sorted_count]
    centroids=np.concatenate(sorted_centroids)
    X[idx,:]=centroids
    #label sample
    if filename[0]=='c':
        y[idx]=1
    else:
        y[idx]=0
#training and validation set splitting: 70% for training and 30% for validation set
x,x_valid,y,y_valid=model_selection.train_test_split(X,y,test_size=0.25)
# Out:
# (200000, 3)
# Number of iterations: 1
# Number of samples each cluster:
#  [[74909.]
#  [58376.]
#  [66715.]]
# Centroids:
#  [[0.5693795  0.72356157 0.87501721]
#  [0.1692118  0.20063114 0.0900806 ]
#  [0.39697368 0.45846335 0.1840565 ]]
# ------------------------------------------------
# Number of iterations: 2
# Number of samples each cluster:
#  [[76664.]
#  [67690.]
#  [55646.]]
# Centroids:
#  [[0.54939409 0.71647744 0.87937878]
#  [0.17992431 0.21828393 0.09434159]
#  [0.44416187 0.48154466 0.16680194]]
# ------------------------------------------------
# Number of iterations: 3
# Number of samples each cluster:
#  [[76610.]
#  [76522.]
#  [46868.]]
# Centroids:
#  [[0.5490714  0.7163923  0.87976711]
#  [0.19275216 0.23195952 0.10215286]
#  [0.4736604  0.50923614 0.16788937]]
# ------------------------------------------------
# Number of iterations: 4
# Number of samples each cluster:
#  [[76551.]
#  [83518.]
#  [39931.]]
# Centroids:
#  [[0.54897106 0.71642772 0.88007164]
#  [0.20309578 0.24227306 0.10832436]
#  [0.50154567 0.53648242 0.16696652]]
# ------------------------------------------------
# Number of iterations: 5
# Number of samples each cluster:
#  [[76523.]
#  [88782.]
#  [34695.]]
# Centroids:
#  [[0.54885724 0.71641361 0.88022625]
#  [0.21112619 0.2499796  0.1130811 ]
#  [0.52656721 0.56157636 0.16392618]]
# ------------------------------------------------
# Number of iterations: 6
# Number of samples each cluster:
#  [[76509.]
#  [92495.]
#  [30996.]]
# Centroids:
#  [[0.5487998  0.71639709 0.88030016]
#  [0.21705068 0.2554822  0.11669088]
#  [0.54682635 0.58259286 0.15938607]]
# ------------------------------------------------
# Number of iterations: 7
# Number of samples each cluster:
#  [[76511.]
#  [94967.]
#  [28522.]]
# Centroids:
#  [[0.54877023 0.71636552 0.88029172]
#  [0.22119634 0.25922125 0.11933422]
#  [0.56168377 0.59856929 0.15425728]]
# ------------------------------------------------
# Number of iterations: 8
# Number of samples each cluster:
#  [[76513.]
#  [96516.]
#  [26971.]]
# Centroids:
#  [[0.54873957 0.71633936 0.8802862 ]
#  [0.22393497 0.26160474 0.12109324]
#  [0.57152642 0.60959486 0.14993012]]
# ------------------------------------------------
# Number of iterations: 9
# Number of samples each cluster:
#  [[76525.]
#  [97531.]
#  [25944.]]
# Centroids:
#  [[0.54872598 0.71630729 0.88023221]
#  [0.22578906 0.26320658 0.12226686]
#  [0.57820567 0.61723262 0.14646774]]
# ------------------------------------------------
# Number of iterations: 10
# Number of samples each cluster:
#  [[76527.]
#  [98143.]
#  [25330.]]
# Centroids:
#  [[0.54873429 0.71630465 0.88022033]
#  [0.22693407 0.26418293 0.12298953]
#  [0.58226124 0.62200349 0.14423041]]
# ------------------------------------------------
# Number of iterations: 11
# Number of samples each cluster:
#  [[76528.]
#  [98483.]
#  [24989.]]
# Centroids:
#  [[0.54873716 0.71630438 0.88021513]
#  [0.22757515 0.26474028 0.12338907]
#  [0.58456182 0.62467249 0.14293125]]
# ------------------------------------------------
# Number of iterations: 12
# Number of samples each cluster:
#  [[76529.]
#  [98668.]
#  [24803.]]
# Centroids:
#  [[0.54873858 0.71630329 0.88021044]
#  [0.2279271  0.26504581 0.12361468]
#  [0.58582153 0.6261414  0.14216428]]
# ------------------------------------------------
# Number of iterations: 13
# Number of samples each cluster:
#  [[76531.]
#  [98765.]
#  [24704.]]
# Centroids:
#  [[0.54873768 0.716299   0.88020111]
#  [0.22811526 0.26520412 0.12373593]
#  [0.58648031 0.62693233 0.14172148]]
# ------------------------------------------------
# Number of iterations: 14
# Number of samples each cluster:
#  [[76536.]
#  [98815.]
#  [24649.]]
# Centroids:
#  [[0.5487337  0.7162862  0.88017793]
#  [0.22821271 0.26528568 0.12379992]
#  [0.58683659 0.62736074 0.14142366]]
# ------------------------------------------------
# Number of iterations: 15
# Number of samples each cluster:
#  [[76537.]
#  [98835.]
#  [24628.]]
# Centroids:
#  [[0.54873474 0.71628507 0.88017321]
#  [0.22825335 0.26531683 0.12382436]
#  [0.58696305 0.62752963 0.14132455]]
# ------------------------------------------------
# Number of iterations: 16
# Number of samples each cluster:
#  [[76537.]
#  [98851.]
#  [24612.]]
# Centroids:
#  [[0.54873474 0.71628507 0.88017321]
#  [0.22828403 0.2653436  0.12384436]
#  [0.58707302 0.6276576  0.1412556 ]]
# ------------------------------------------------
# Number of iterations: 17
# Number of samples each cluster:
#  [[76537.]
#  [98858.]
#  [24605.]]
# Centroids:
#  [[0.54873474 0.71628507 0.88017321]
#  [0.22829675 0.26535607 0.12385169]
#  [0.58712397 0.62771055 0.14123108]]
# ------------------------------------------------
# Number of iterations: 18
# Number of samples each cluster:
#  [[76537.]
#  [98858.]
#  [24605.]]
# Centroids:
#  [[0.54873474 0.71628507 0.88017321]
#  [0.22829675 0.26535607 0.12385169]
#  [0.58712397 0.62771055 0.14123108]]
# ------------------------------------------------
# Number of iterations: 19
# Number of samples each cluster:
#  [[76537.]
#  [98858.]
#  [24605.]]
# Centroids:
#  [[0.54873474 0.71628507 0.88017321]
#  [0.22829675 0.26535607 0.12385169]
#  [0.58712397 0.62771055 0.14123108]]
# ------------------------------------------------
# Number of iterations: 20
# Number of samples each cluster:
#  [[76537.]
#  [98858.]
#  [24605.]]
# Centroids:
#  [[0.54873474 0.71628507 0.88017321]
#  [0.22829675 0.26535607 0.12385169]
#  [0.58712397 0.62771055 0.14123108]]
# ------------------------------------------------
# (200000, 3)
# Number of iterations: 1
# Number of samples each cluster:
#  [[ 70474.]
#  [111701.]
#  [ 17825.]]
# Centroids:
#  [[0.55360797 0.67181217 0.70639873]
#  [0.31667445 0.34728226 0.17048733]
#  [0.56189209 0.55905765 0.1907905 ]]
# ------------------------------------------------
# Number of iterations: 2
# Number of samples each cluster:
#  [[63783.]
#  [77703.]
#  [58514.]]
# Centroids:
#  [[0.54790553 0.68183917 0.75142551]
#  [0.24116397 0.28289371 0.1748387 ]
#  [0.52495685 0.52347869 0.18309337]]
# ------------------------------------------------
# Number of iterations: 3
# Number of samples each cluster:
#  [[63606.]
#  [66091.]
#  [70303.]]
# Centroids:
#  [[0.54795934 0.6822281  0.75219557]
#  [0.21028788 0.25674347 0.17940912]
#  [0.50711789 0.50837142 0.17816751]]
# ------------------------------------------------
# Number of iterations: 4
# Number of samples each cluster:
#  [[63674.]
#  [63012.]
#  [73314.]]
# Centroids:
#  [[0.54793819 0.68208696 0.75190789]
#  [0.20270538 0.24984595 0.1769643 ]
#  [0.5011493  0.50369331 0.18003837]]
# ------------------------------------------------
# Number of iterations: 5
# Number of samples each cluster:
#  [[63641.]
#  [61630.]
#  [74729.]]
# Centroids:
#  [[0.54808321 0.68222002 0.75201939]
#  [0.19974604 0.24640451 0.17306941]
#  [0.4979678  0.50180244 0.18335126]]
# ------------------------------------------------
# Number of iterations: 6
# Number of samples each cluster:
#  [[63593.]
#  [60710.]
#  [75697.]]
# Centroids:
#  [[0.54823535 0.68238631 0.75219229]
#  [0.19787733 0.24404983 0.16978397]
#  [0.49574598 0.5005616  0.18607661]]
# ------------------------------------------------
# Number of iterations: 7
# Number of samples each cluster:
#  [[63562.]
#  [59977.]
#  [76461.]]
# Centroids:
#  [[0.54829268 0.68247523 0.75231249]
#  [0.19648989 0.24210399 0.16680192]
#  [0.49395239 0.49962867 0.18838917]]
# ------------------------------------------------
# Number of iterations: 8
# Number of samples each cluster:
#  [[63535.]
#  [59296.]
#  [77169.]]
# Centroids:
#  [[0.54835884 0.68255793 0.75241318]
#  [0.19519867 0.2403124  0.1641213 ]
#  [0.49228406 0.4987286  0.19037285]]
# ------------------------------------------------
# Number of iterations: 9
# Number of samples each cluster:
#  [[63513.]
#  [58683.]
#  [77804.]]
# Centroids:
#  [[0.54842827 0.6826316  0.75249115]
#  [0.1940654  0.2386857  0.16157235]
#  [0.49075732 0.49791137 0.19218381]]
# ------------------------------------------------
# Number of iterations: 10
# Number of samples each cluster:
#  [[63496.]
#  [58082.]
#  [78422.]]
# Centroids:
#  [[0.5484591  0.68268189 0.7525557 ]
#  [0.19296586 0.23708855 0.15907073]
#  [0.48928547 0.49710697 0.1938712 ]]
# ------------------------------------------------
# Number of iterations: 11
# Number of samples each cluster:
#  [[63482.]
#  [57478.]
#  [79040.]]
# Centroids:
#  [[0.54849003 0.68272216 0.75260826]
#  [0.19187783 0.23546962 0.15654253]
#  [0.48779794 0.49629781 0.19550053]]
# ------------------------------------------------
# Number of iterations: 12
# Number of samples each cluster:
#  [[63470.]
#  [56834.]
#  [79696.]]
# Centroids:
#  [[0.54851882 0.68275806 0.7526524 ]
#  [0.19074401 0.23372628 0.15372159]
#  [0.48620148 0.49543285 0.19724616]]
# ------------------------------------------------
# Number of iterations: 13
# Number of samples each cluster:
#  [[63459.]
#  [56161.]
#  [80380.]]
# Centroids:
#  [[0.54854557 0.68278958 0.75269311]
#  [0.18957948 0.23188141 0.15075415]
#  [0.48452874 0.4945314  0.19899894]]
# ------------------------------------------------
# Number of iterations: 14
# Number of samples each cluster:
#  [[63443.]
#  [55539.]
#  [81018.]]
# Centroids:
#  [[0.54857669 0.68283385 0.75275346]
#  [0.18846726 0.23019989 0.14810841]
#  [0.48301505 0.49367017 0.20050433]]
# ------------------------------------------------
# Number of iterations: 15
# Number of samples each cluster:
#  [[63431.]
#  [55046.]
#  [81523.]]
# Centroids:
#  [[0.5486099  0.68287113 0.75279598]
#  [0.18756512 0.22887986 0.14609492]
#  [0.48182677 0.49296702 0.20159522]]
# ------------------------------------------------
# Number of iterations: 16
# Number of samples each cluster:
#  [[63422.]
#  [54659.]
#  [81919.]]
# Centroids:
#  [[0.54863141 0.68289805 0.75282849]
#  [0.1868393  0.22785467 0.14457237]
#  [0.48091159 0.49240348 0.20238431]]
# ------------------------------------------------
# Number of iterations: 17
# Number of samples each cluster:
#  [[63419.]
#  [54385.]
#  [82196.]]
# Centroids:
#  [[0.54863572 0.68290552 0.75284016]
#  [0.18633496 0.22712123 0.14348818]
#  [0.48026414 0.49200808 0.20292004]]
# ------------------------------------------------
# Number of iterations: 18
# Number of samples each cluster:
#  [[63416.]
#  [54203.]
#  [82381.]]
# Centroids:
#  [[0.54864015 0.68291366 0.75285156]
#  [0.18599828 0.22663762 0.14276771]
#  [0.47983538 0.49174176 0.20327403]]
# ------------------------------------------------
# Number of iterations: 19
# Number of samples each cluster:
#  [[63415.]
#  [54075.]
#  [82510.]]
# Centroids:
#  [[0.54864335 0.68291707 0.7528549 ]
#  [0.18574886 0.22630116 0.14231062]
#  [0.47954138 0.4915507  0.20348382]]
# ------------------------------------------------
# Number of iterations: 20
# Number of samples each cluster:
#  [[63414.]
#  [53989.]
#  [82597.]]
# Centroids:
#  [[0.54864687 0.68292055 0.75285818]
#  [0.18557545 0.22608066 0.14200743]
#  [0.47934697 0.4914183  0.20362244]]
# ------------------------------------------------
# (200000, 3)
# Number of iterations: 1
# Number of samples each cluster:
#  [[65154.]
#  [55559.]
#  [79287.]]
# Centroids:
#  [[0.59635047 0.57004364 0.29515082]
#  [0.82218049 0.80204646 0.67091149]
#  [0.22774418 0.22973829 0.12895956]]
# ------------------------------------------------
# Number of iterations: 2
# Number of samples each cluster:
#  [[71088.]
#  [56753.]
#  [72159.]]
# Centroids:
#  [[0.5801493  0.55460591 0.28542728]
#  [0.81948698 0.79926814 0.66807779]
#  [0.20567495 0.20967714 0.11813318]]
# ------------------------------------------------
# Number of iterations: 3
# Number of samples each cluster:
#  [[72927.]
#  [57031.]
#  [70042.]]
# Centroids:
#  [[0.57454933 0.54940151 0.28258956]
#  [0.81879241 0.798544   0.66733768]
#  [0.19980281 0.20428908 0.11511523]]
# ------------------------------------------------
# Number of iterations: 4
# Number of samples each cluster:
#  [[73501.]
#  [57119.]
#  [69380.]]
# Centroids:
#  [[0.57274925 0.54773111 0.28167718]
#  [0.81856441 0.79830991 0.66709778]
#  [0.19801202 0.20264247 0.11419333]]
# ------------------------------------------------
# Number of iterations: 5
# Number of samples each cluster:
#  [[73691.]
#  [57143.]
#  [69166.]]
# Centroids:
#  [[0.57216756 0.54719421 0.28139867]
#  [0.81849887 0.79824463 0.66703427]
#  [0.19744117 0.20211378 0.11389059]]
# ------------------------------------------------
# Number of iterations: 6
# Number of samples each cluster:
#  [[73733.]
#  [57152.]
#  [69115.]]
# Centroids:
#  [[0.57202422 0.54705984 0.28132149]
#  [0.81847676 0.79822167 0.66700776]
#  [0.19730379 0.20198879 0.11382103]]
# ------------------------------------------------
# Number of iterations: 7
# Number of samples each cluster:
#  [[73747.]
#  [57153.]
#  [69100.]]
# Centroids:
#  [[0.57198329 0.54702203 0.28130513]
#  [0.81847536 0.79821991 0.66700361]
#  [0.19726372 0.20195205 0.11379998]]
# ------------------------------------------------
# Number of iterations: 8
# Number of samples each cluster:
#  [[73751.]
#  [57153.]
#  [69096.]]
# Centroids:
#  [[0.57197306 0.54701222 0.28130168]
#  [0.81847536 0.79821991 0.66700361]
#  [0.19725295 0.20194254 0.11379396]]
# ------------------------------------------------
# Number of iterations: 9
# Number of samples each cluster:
#  [[73753.]
#  [57153.]
#  [69094.]]
# Centroids:
#  [[0.57196802 0.54700729 0.28129983]
#  [0.81847536 0.79821991 0.66700361]
#  [0.19724748 0.20193781 0.11379109]]
# ------------------------------------------------
# Number of iterations: 10
# Number of samples each cluster:
#  [[73753.]
#  [57153.]
#  [69094.]]
# Centroids:
#  [[0.57196802 0.54700729 0.28129983]
#  [0.81847536 0.79821991 0.66700361]
#  [0.19724748 0.20193781 0.11379109]]
# ------------------------------------------------
# Number of iterations: 11
# Number of samples each cluster:
#  [[73753.]
#  [57153.]
#  [69094.]]
# Centroids:
#  [[0.57196802 0.54700729 0.28129983]
#  [0.81847536 0.79821991 0.66700361]
#  [0.19724748 0.20193781 0.11379109]]
# ------------------------------------------------
# Number of iterations: 12
# Number of samples each cluster:
#  [[73753.]
#  [57153.]
#  [69094.]]
# Centroids:
#  [[0.57196802 0.54700729 0.28129983]
#  [0.81847536 0.79821991 0.66700361]
#  [0.19724748 0.20193781 0.11379109]]
# ------------------------------------------------
# Number of iterations: 13
# Number of samples each cluster:
#  [[73753.]
#  [57153.]
#  [69094.]]
# Centroids:
#  [[0.57196802 0.54700729 0.28129983]
#  [0.81847536 0.79821991 0.66700361]
#  [0.19724748 0.20193781 0.11379109]]
# ------------------------------------------------
# Number of iterations: 14
# Number of samples each cluster:
#  [[73753.]
#  [57153.]
#  [69094.]]
# Centroids:
#  [[0.57196802 0.54700729 0.28129983]
#  [0.81847536 0.79821991 0.66700361]
#  [0.19724748 0.20193781 0.11379109]]
# ------------------------------------------------
# Number of iterations: 15
# Number of samples each cluster:
#  [[73753.]
#  [57153.]
#  [69094.]]
# Centroids:
#  [[0.57196802 0.54700729 0.28129983]
#  [0.81847536 0.79821991 0.66700361]
#  [0.19724748 0.20193781 0.11379109]]
# ------------------------------------------------
# Number of iterations: 16
# Number of samples each cluster:
#  [[73753.]
#  [57153.]
#  [69094.]]
# Centroids:
#  [[0.57196802 0.54700729 0.28129983]
#  [0.81847536 0.79821991 0.66700361]
#  [0.19724748 0.20193781 0.11379109]]
# ------------------------------------------------
# Number of iterations: 17
# Number of samples each cluster:
#  [[73753.]
#  [57153.]
#  [69094.]]
# Centroids:
#  [[0.57196802 0.54700729 0.28129983]
#  [0.81847536 0.79821991 0.66700361]
#  [0.19724748 0.20193781 0.11379109]]
# ------------------------------------------------
# Number of iterations: 18
# Number of samples each cluster:
#  [[73753.]
#  [57153.]
#  [69094.]]
# Centroids:
#  [[0.57196802 0.54700729 0.28129983]
#  [0.81847536 0.79821991 0.66700361]
#  [0.19724748 0.20193781 0.11379109]]
# ------------------------------------------------
# Number of iterations: 19
# Number of samples each cluster:
#  [[73753.]
#  [57153.]
#  [69094.]]
# Centroids:
#  [[0.57196802 0.54700729 0.28129983]
#  [0.81847536 0.79821991 0.66700361]
#  [0.19724748 0.20193781 0.11379109]]
# ------------------------------------------------
# Number of iterations: 20
# Number of samples each cluster:
#  [[73753.]
#  [57153.]
#  [69094.]]
# Centroids:
#  [[0.57196802 0.54700729 0.28129983]
#  [0.81847536 0.79821991 0.66700361]
#  [0.19724748 0.20193781 0.11379109]]
# ------------------------------------------------
# (200000, 3)
# Number of iterations: 1
# Number of samples each cluster:
#  [[ 77819.]
#  [  3309.]
#  [118872.]]
# Centroids:
#  [[0.55633624 0.789258   0.96656862]
#  [0.89234602 0.79369039 0.65464429]
#  [0.53975201 0.54554507 0.28273453]]
# ------------------------------------------------
# Number of iterations: 2
# Number of samples each cluster:
#  [[ 78231.]
#  [ 19703.]
#  [102066.]]
# Centroids:
#  [[0.5533215  0.78670519 0.96424581]
#  [0.82465605 0.73479622 0.50896979]
#  [0.49842859 0.51802951 0.25013908]]
# ------------------------------------------------
# Number of iterations: 3
# Number of samples each cluster:
#  [[78656.]
#  [36638.]
#  [84706.]]
# Centroids:
#  [[0.55531992 0.78739616 0.96416408]
#  [0.78836156 0.69534608 0.42790187]
#  [0.44677437 0.48976579 0.22994926]]
# ------------------------------------------------
# Number of iterations: 4
# Number of samples each cluster:
#  [[79097.]
#  [46827.]
#  [74076.]]
# Centroids:
#  [[0.5569885  0.78764883 0.96308222]
#  [0.76526385 0.67494279 0.39242284]
#  [0.41196305 0.47234486 0.22193345]]
# ------------------------------------------------
# Number of iterations: 5
# Number of samples each cluster:
#  [[79271.]
#  [51770.]
#  [68959.]]
# Centroids:
#  [[0.55784404 0.78780722 0.9625562 ]
#  [0.75123645 0.66682758 0.37777845]
#  [0.39581981 0.46293731 0.21944137]]
# ------------------------------------------------
# Number of iterations: 6
# Number of samples each cluster:
#  [[79344.]
#  [54204.]
#  [66452.]]
# Centroids:
#  [[0.55828441 0.78789933 0.96233425]
#  [0.7435935  0.66329841 0.37116279]
#  [0.38833209 0.45788105 0.21848679]]
# ------------------------------------------------
# Number of iterations: 7
# Number of samples each cluster:
#  [[79380.]
#  [55492.]
#  [65128.]]
# Centroids:
#  [[0.55854326 0.78796471 0.96221982]
#  [0.73938264 0.66160272 0.36774741]
#  [0.38448469 0.45500133 0.21810576]]
# ------------------------------------------------
# Number of iterations: 8
# Number of samples each cluster:
#  [[79407.]
#  [56220.]
#  [64373.]]
# Centroids:
#  [[0.55868239 0.78798493 0.96213189]
#  [0.73697271 0.66064189 0.36584607]
#  [0.38233119 0.45333939 0.21787034]]
# ------------------------------------------------
# Number of iterations: 9
# Number of samples each cluster:
#  [[79424.]
#  [56563.]
#  [64013.]]
# Centroids:
#  [[0.55877913 0.78799921 0.96207539]
#  [0.73576938 0.66022426 0.36492289]
#  [0.38132735 0.45249104 0.21776562]]
# ------------------------------------------------
# Number of iterations: 10
# Number of samples each cluster:
#  [[79426.]
#  [56761.]
#  [63813.]]
# Centroids:
#  [[0.55881106 0.78801121 0.96206848]
#  [0.73513576 0.65996829 0.36443466]
#  [0.38074586 0.45204872 0.21772857]]
# ------------------------------------------------
# Number of iterations: 11
# Number of samples each cluster:
#  [[79432.]
#  [56851.]
#  [63717.]]
# Centroids:
#  [[0.55885105 0.78801966 0.96204955]
#  [0.73479428 0.65984882 0.36419242]
#  [0.38048336 0.45181946 0.217691  ]]
# ------------------------------------------------
# Number of iterations: 12
# Number of samples each cluster:
#  [[79433.]
#  [56920.]
#  [63647.]]
# Centroids:
#  [[0.55885976 0.78802218 0.96204731]
#  [0.73457332 0.65975684 0.36402207]
#  [0.38028318 0.45166776 0.21767562]]
# ------------------------------------------------
# Number of iterations: 13
# Number of samples each cluster:
#  [[79433.]
#  [56962.]
#  [63605.]]
# Centroids:
#  [[0.55885976 0.78802218 0.96204731]
#  [0.73443849 0.65971771 0.36392521]
#  [0.38016998 0.4515654  0.21766573]]
# ------------------------------------------------
# Number of iterations: 14
# Number of samples each cluster:
#  [[79433.]
#  [56979.]
#  [63588.]]
# Centroids:
#  [[0.55886416 0.78802389 0.96204824]
#  [0.73437112 0.65970567 0.36389206]
#  [0.38013015 0.4515184  0.21765517]]
# ------------------------------------------------
# Number of iterations: 15
# Number of samples each cluster:
#  [[79433.]
#  [56996.]
#  [63571.]]
# Centroids:
#  [[0.55886416 0.78802389 0.96204824]
#  [0.7343113  0.65969438 0.36385909]
#  [0.38008905 0.45147285 0.21764563]]
# ------------------------------------------------
# Number of iterations: 16
# Number of samples each cluster:
#  [[79433.]
#  [57005.]
#  [63562.]]
# Centroids:
#  [[0.55886416 0.78802389 0.96204824]
#  [0.73428211 0.65968299 0.36384334]
#  [0.38006507 0.45145358 0.21763905]]
# ------------------------------------------------
# Number of iterations: 17
# Number of samples each cluster:
#  [[79433.]
#  [57008.]
#  [63559.]]
# Centroids:
#  [[0.55886416 0.78802389 0.96204824]
#  [0.73427198 0.65968097 0.36383654]
#  [0.38005744 0.45144556 0.21763825]]
# ------------------------------------------------
# Number of iterations: 18
# Number of samples each cluster:
#  [[79433.]
#  [57012.]
#  [63555.]]
# Centroids:
#  [[0.55886416 0.78802389 0.96204824]
#  [0.73425695 0.65968019 0.36382844]
#  [0.38004863 0.45143315 0.21763632]]
# ------------------------------------------------
# Number of iterations: 19
# Number of samples each cluster:
#  [[79433.]
#  [57014.]
#  [63553.]]
# Centroids:
#  [[0.55886416 0.78802389 0.96204824]
#  [0.73425184 0.6596767  0.36382295]
#  [0.38004206 0.45142973 0.21763664]]
# ------------------------------------------------
# Number of iterations: 20
# Number of samples each cluster:
#  [[79433.]
#  [57014.]
#  [63553.]]
# Centroids:
#  [[0.55886416 0.78802389 0.96204824]
#  [0.73425184 0.6596767  0.36382295]
#  [0.38004206 0.45142973 0.21763664]]
# ------------------------------------------------
# (200000, 3)
# Number of iterations: 1
# Number of samples each cluster:
#  [[ 35377.]
#  [124746.]
#  [ 39877.]]
# Centroids:
#  [[0.80655743 0.83251994 0.85318739]
#  [0.26741787 0.31778028 0.13573815]
#  [0.74543341 0.74561447 0.74427761]]
# ------------------------------------------------
# Number of iterations: 2
# Number of samples each cluster:
#  [[ 44218.]
#  [123961.]
#  [ 31821.]]
# Centroids:
#  [[0.80518046 0.82608847 0.84287714]
#  [0.2656327  0.3163977  0.13373451]
#  [0.72552637 0.7252377  0.7211387 ]]
# ------------------------------------------------
# Number of iterations: 3
# Number of samples each cluster:
#  [[ 49432.]
#  [123643.]
#  [ 26925.]]
# Centroids:
#  [[0.8030536  0.82135149 0.83644273]
#  [0.26495286 0.31588292 0.13300623]
#  [0.71169649 0.71194005 0.70578395]]
# ------------------------------------------------
# Number of iterations: 4
# Number of samples each cluster:
#  [[ 52972.]
#  [123384.]
#  [ 23644.]]
# Centroids:
#  [[0.80106878 0.8178583  0.83199248]
#  [0.26443064 0.31548279 0.13241708]
#  [0.70029666 0.70113459 0.6929921 ]]
# ------------------------------------------------
# Number of iterations: 5
# Number of samples each cluster:
#  [[ 55457.]
#  [123149.]
#  [ 21394.]]
# Centroids:
#  [[0.79949531 0.81534865 0.82879795]
#  [0.26394455 0.31512398 0.13191661]
#  [0.6906806  0.69191135 0.68185067]]
# ------------------------------------------------
# Number of iterations: 6
# Number of samples each cluster:
#  [[ 57453.]
#  [122917.]
#  [ 19630.]]
# Centroids:
#  [[0.79806824 0.81322079 0.8261692 ]
#  [0.26343936 0.3147646  0.13146802]
#  [0.68191286 0.68338511 0.6709122 ]]
# ------------------------------------------------
# Number of iterations: 7
# Number of samples each cluster:
#  [[ 59208.]
#  [122653.]
#  [ 18139.]]
# Centroids:
#  [[0.79673058 0.81130308 0.82380536]
#  [0.26288204 0.31436222 0.13096178]
#  [0.67271872 0.67443862 0.65917834]]
# ------------------------------------------------
# Number of iterations: 8
# Number of samples each cluster:
#  [[ 61090.]
#  [122320.]
#  [ 16590.]]
# Centroids:
#  [[0.79516991 0.80920156 0.8212656 ]
#  [0.26213451 0.31384582 0.13039094]
#  [0.6616827  0.66323086 0.64346136]]
# ------------------------------------------------
# Number of iterations: 9
# Number of samples each cluster:
#  [[ 63501.]
#  [121801.]
#  [ 14698.]]
# Centroids:
#  [[0.79299541 0.80639333 0.81798494]
#  [0.2609379  0.31305103 0.12956636]
#  [0.64498849 0.64566829 0.61718502]]
# ------------------------------------------------
# Number of iterations: 10
# Number of samples each cluster:
#  [[ 66072.]
#  [120882.]
#  [ 13046.]]
# Centroids:
#  [[0.7904831  0.80324638 0.81434688]
#  [0.2588371  0.31168044 0.12818857]
#  [0.62095617 0.6192009  0.57445514]]
# ------------------------------------------------
# Number of iterations: 11
# Number of samples each cluster:
#  [[ 69754.]
#  [119073.]
#  [ 11173.]]
# Centroids:
#  [[0.78652215 0.79849675 0.80885761]
#  [0.25472959 0.30906575 0.12576021]
#  [0.57496259 0.56627732 0.48329542]]
# ------------------------------------------------
# Number of iterations: 12
# Number of samples each cluster:
#  [[ 71538.]
#  [115666.]
#  [ 12796.]]
# Centroids:
#  [[0.78425062 0.7959178  0.80589923]
#  [0.24783636 0.30453866 0.12151655]
#  [0.53521243 0.52075712 0.39760913]]
# ------------------------------------------------
# Number of iterations: 13
# Number of samples each cluster:
#  [[ 71868.]
#  [112116.]
#  [ 16016.]]
# Centroids:
#  [[0.78369665 0.79529457 0.80511066]
#  [0.24199469 0.30031162 0.11780007]
#  [0.50976221 0.49954895 0.3575546 ]]
# ------------------------------------------------
# Number of iterations: 14
# Number of samples each cluster:
#  [[ 72249.]
#  [107994.]
#  [ 19757.]]
# Centroids:
#  [[0.78278421 0.79443664 0.80417683]
#  [0.23609588 0.29504986 0.11440611]
#  [0.48419423 0.48417659 0.32086929]]
# ------------------------------------------------
# Number of iterations: 15
# Number of samples each cluster:
#  [[ 72992.]
#  [101731.]
#  [ 25277.]]
# Centroids:
#  [[0.78075089 0.79264236 0.80232813]
#  [0.2274453  0.2866219  0.11013921]
#  [0.45463198 0.46729678 0.27801767]]
# ------------------------------------------------
# Number of iterations: 16
# Number of samples each cluster:
#  [[73721.]
#  [92025.]
#  [34254.]]
# Centroids:
#  [[0.77864292 0.79077904 0.8004094 ]
#  [0.21403449 0.27279661 0.10426579]
#  [0.4238828  0.45033032 0.23919889]]
# ------------------------------------------------
# Number of iterations: 17
# Number of samples each cluster:
#  [[74443.]
#  [80560.]
#  [44997.]]
# Centroids:
#  [[0.77642457 0.78880151 0.79838211]
#  [0.19753756 0.25521031 0.09760422]
#  [0.3979274  0.43439009 0.21109417]]
# ------------------------------------------------
# Number of iterations: 18
# Number of samples each cluster:
#  [[74774.]
#  [70718.]
#  [54508.]]
# Centroids:
#  [[0.77544869 0.78787052 0.79733447]
#  [0.18239558 0.23892828 0.09173282]
#  [0.38043019 0.42228634 0.19609067]]
# ------------------------------------------------
# Number of iterations: 19
# Number of samples each cluster:
#  [[74911.]
#  [63948.]
#  [61141.]]
# Centroids:
#  [[0.77506537 0.78747494 0.79685236]
#  [0.17137837 0.22700333 0.08747123]
#  [0.36960981 0.41412146 0.18823609]]
# ------------------------------------------------
# Number of iterations: 20
# Number of samples each cluster:
#  [[74985.]
#  [59684.]
#  [65331.]]
# Centroids:
#  [[0.77485733 0.78725756 0.79658248]
#  [0.16413559 0.21914728 0.0846607 ]
#  [0.36306798 0.4089123  0.18384738]]
# ------------------------------------------------
# (200000, 3)
# Number of iterations: 1
# Number of samples each cluster:
#  [[85556.]
#  [72521.]
#  [41923.]]
# Centroids:
#  [[0.62367987 0.72900437 0.8116425 ]
#  [0.09345755 0.11799652 0.06603317]
#  [0.29504183 0.33908085 0.17606515]]
# ------------------------------------------------
# Number of iterations: 2
# Number of samples each cluster:
#  [[75121.]
#  [67164.]
#  [57715.]]
# Centroids:
#  [[0.65022167 0.76887597 0.87040932]
#  [0.08536738 0.10766964 0.06102941]
#  [0.3106179  0.34918054 0.2100989 ]]
# ------------------------------------------------
# Number of iterations: 3
# Number of samples each cluster:
#  [[74391.]
#  [68745.]
#  [56864.]]
# Centroids:
#  [[0.65181164 0.77121088 0.87390316]
#  [0.08782207 0.1109324  0.06187802]
#  [0.31619268 0.35428415 0.21712369]]
# ------------------------------------------------
# Number of iterations: 4
# Number of samples each cluster:
#  [[74318.]
#  [70004.]
#  [55678.]]
# Centroids:
#  [[0.65195299 0.77143087 0.87423212]
#  [0.0897765  0.11339424 0.06283569]
#  [0.31915068 0.35694458 0.21985207]]
# ------------------------------------------------
# Number of iterations: 5
# Number of samples each cluster:
#  [[74298.]
#  [70736.]
#  [54966.]]
# Centroids:
#  [[0.65199564 0.77149172 0.87431857]
#  [0.09091019 0.11482703 0.06340694]
#  [0.32080982 0.35841272 0.22132921]]
# ------------------------------------------------
# Number of iterations: 6
# Number of samples each cluster:
#  [[74283.]
#  [71137.]
#  [54580.]]
# Centroids:
#  [[0.65202806 0.77153522 0.87438403]
#  [0.0915422  0.11562368 0.06369035]
#  [0.32172208 0.35921835 0.22221045]]
# ------------------------------------------------
# Number of iterations: 7
# Number of samples each cluster:
#  [[74280.]
#  [71387.]
#  [54333.]]
# Centroids:
#  [[0.65203521 0.77154419 0.87439658]
#  [0.09193266 0.11612071 0.06387291]
#  [0.32227663 0.35969666 0.22271884]]
# ------------------------------------------------
# Number of iterations: 8
# Number of samples each cluster:
#  [[74276.]
#  [71530.]
#  [54194.]]
# Centroids:
#  [[0.6520441  0.77155658 0.87441332]
#  [0.09215132 0.11640462 0.06398467]
#  [0.32260798 0.35997806 0.22301563]]
# ------------------------------------------------
# Number of iterations: 9
# Number of samples each cluster:
#  [[74273.]
#  [71611.]
#  [54116.]]
# Centroids:
#  [[0.65205041 0.77156577 0.87442609]
#  [0.09227563 0.1165735  0.06403503]
#  [0.32279803 0.36012936 0.2232056 ]]
# ------------------------------------------------
# Number of iterations: 10
# Number of samples each cluster:
#  [[74271.]
#  [71655.]
#  [54074.]]
# Centroids:
#  [[0.65205702 0.77157197 0.87443335]
#  [0.09234306 0.11666527 0.06406254]
#  [0.32289935 0.36021264 0.22331279]]
# ------------------------------------------------
# Number of iterations: 11
# Number of samples each cluster:
#  [[74271.]
#  [71685.]
#  [54044.]]
# Centroids:
#  [[0.65205702 0.77157197 0.87443335]
#  [0.09239165 0.11672692 0.06407896]
#  [0.3229629  0.36026606 0.2233794 ]]
# ------------------------------------------------
# Number of iterations: 12
# Number of samples each cluster:
#  [[74271.]
#  [71704.]
#  [54025.]]
# Centroids:
#  [[0.65205702 0.77157197 0.87443335]
#  [0.09241849 0.11676487 0.06409671]
#  [0.32300836 0.36030135 0.22341187]]
# ------------------------------------------------
# Number of iterations: 13
# Number of samples each cluster:
#  [[74271.]
#  [71717.]
#  [54012.]]
# Centroids:
#  [[0.65205702 0.77157197 0.87443335]
#  [0.09243824 0.1167924  0.06410444]
#  [0.32303763 0.3603234  0.22343995]]
# ------------------------------------------------
# Number of iterations: 14
# Number of samples each cluster:
#  [[74271.]
#  [71725.]
#  [54004.]]
# Centroids:
#  [[0.65205702 0.77157197 0.87443335]
#  [0.09245141 0.11680635 0.06411232]
#  [0.3230543  0.36034095 0.22345309]]
# ------------------------------------------------
# Number of iterations: 15
# Number of samples each cluster:
#  [[74271.]
#  [71734.]
#  [53995.]]
# Centroids:
#  [[0.65205702 0.77157197 0.87443335]
#  [0.09246513 0.11682563 0.06411727]
#  [0.32307451 0.36035593 0.22347308]]
# ------------------------------------------------
# Number of iterations: 16
# Number of samples each cluster:
#  [[74270.]
#  [71735.]
#  [53995.]]
# Centroids:
#  [[0.65205867 0.77157466 0.87443807]
#  [0.0924667  0.11682737 0.06411837]
#  [0.32308052 0.36036205 0.22348013]]
# ------------------------------------------------
# Number of iterations: 17
# Number of samples each cluster:
#  [[74270.]
#  [71739.]
#  [53991.]]
# Centroids:
#  [[0.65205867 0.77157466 0.87443807]
#  [0.09247275 0.11683473 0.0641225 ]
#  [0.32308957 0.36037032 0.22348645]]
# ------------------------------------------------
# Number of iterations: 18
# Number of samples each cluster:
#  [[74270.]
#  [71741.]
#  [53989.]]
# Centroids:
#  [[0.65205867 0.77157466 0.87443807]
#  [0.09247576 0.11683976 0.06412251]
#  [0.32309411 0.36037265 0.22349234]]
# ------------------------------------------------
# Number of iterations: 19
# Number of samples each cluster:
#  [[74270.]
#  [71743.]
#  [53987.]]
# Centroids:
#  [[0.65205867 0.77157466 0.87443807]
#  [0.0924784  0.11684382 0.06412454]
#  [0.32309914 0.36037628 0.22349554]]
# ------------------------------------------------
# Number of iterations: 20
# Number of samples each cluster:
#  [[74270.]
#  [71745.]
#  [53985.]]
# Centroids:
#  [[0.65205867 0.77157466 0.87443807]
#  [0.09248074 0.11684742 0.06412772]
#  [0.32310457 0.36038052 0.22349723]]
# ------------------------------------------------
# (200000, 3)
# Number of iterations: 1
# Number of samples each cluster:
#  [[118367.]
#  [ 47336.]
#  [ 34297.]]
# Centroids:
#  [[0.58842323 0.72873312 0.84333247]
#  [0.53257617 0.55624304 0.07667994]
#  [0.85700073 0.79698314 0.21603854]]
# ------------------------------------------------
# Number of iterations: 2
# Number of samples each cluster:
#  [[118403.]
#  [ 39720.]
#  [ 41877.]]
# Centroids:
#  [[0.58858432 0.72886077 0.84335723]
#  [0.49410188 0.52368721 0.07402256]
#  [0.83426693 0.7837774  0.19260517]]
# ------------------------------------------------
# Number of iterations: 3
# Number of samples each cluster:
#  [[118438.]
#  [ 35750.]
#  [ 45812.]]
# Centroids:
#  [[0.58865633 0.72888391 0.84327905]
#  [0.47342839 0.50580869 0.07094328]
#  [0.82092309 0.77517224 0.18443689]]
# ------------------------------------------------
# Number of iterations: 4
# Number of samples each cluster:
#  [[118451.]
#  [ 33754.]
#  [ 47795.]]
# Centroids:
#  [[0.58869967 0.72890339 0.84325549]
#  [0.46284895 0.49645986 0.06912278]
#  [0.81383834 0.77048986 0.18086207]]
# ------------------------------------------------
# Number of iterations: 5
# Number of samples each cluster:
#  [[118459.]
#  [ 32698.]
#  [ 48843.]]
# Centroids:
#  [[0.58872296 0.72891454 0.8432399 ]
#  [0.45717251 0.49148385 0.06793829]
#  [0.81003034 0.76787621 0.17916852]]
# ------------------------------------------------
# Number of iterations: 6
# Number of samples each cluster:
#  [[118461.]
#  [ 32114.]
#  [ 49425.]]
# Centroids:
#  [[0.58873238 0.7289198  0.84323714]
#  [0.45402138 0.48863064 0.06735128]
#  [0.80789486 0.76645324 0.17821538]]
# ------------------------------------------------
# Number of iterations: 7
# Number of samples each cluster:
#  [[118464.]
#  [ 31808.]
#  [ 49728.]]
# Centroids:
#  [[0.58874235 0.7289252  0.8432318 ]
#  [0.45236212 0.48715888 0.06695656]
#  [0.8067681  0.76567447 0.17775826]]
# ------------------------------------------------
# Number of iterations: 8
# Number of samples each cluster:
#  [[118463.]
#  [ 31659.]
#  [ 49878.]]
# Centroids:
#  [[0.58874431 0.72892603 0.84323561]
#  [0.45155463 0.48642916 0.06677872]
#  [0.8062129  0.76530292 0.17754444]]
# ------------------------------------------------
# Number of iterations: 9
# Number of samples each cluster:
#  [[118465.]
#  [ 31577.]
#  [ 49958.]]
# Centroids:
#  [[0.58875055 0.72892863 0.84323156]
#  [0.45111058 0.48602934 0.06667245]
#  [0.80590534 0.7650932  0.17741275]]
# ------------------------------------------------
# Number of iterations: 10
# Number of samples each cluster:
#  [[118465.]
#  [ 31534.]
#  [ 50001.]]
# Centroids:
#  [[0.58875055 0.72892863 0.84323156]
#  [0.45087382 0.48581838 0.06663145]
#  [0.80574954 0.76498625 0.17734338]]
# ------------------------------------------------
# Number of iterations: 11
# Number of samples each cluster:
#  [[118466.]
#  [ 31510.]
#  [ 50024.]]
# Centroids:
#  [[0.58875376 0.72892999 0.84322956]
#  [0.45074326 0.48569471 0.06661797]
#  [0.80565827 0.7649277  0.17729018]]
# ------------------------------------------------
# Number of iterations: 12
# Number of samples each cluster:
#  [[118466.]
#  [ 31500.]
#  [ 50034.]]
# Centroids:
#  [[0.58875376 0.72892999 0.84322956]
#  [0.45069003 0.4856454  0.06660287]
#  [0.80562084 0.76490294 0.17727756]]
# ------------------------------------------------
# Number of iterations: 13
# Number of samples each cluster:
#  [[118466.]
#  [ 31494.]
#  [ 50040.]]
# Centroids:
#  [[0.58875376 0.72892999 0.84322956]
#  [0.45065541 0.48562111 0.06658907]
#  [0.80560008 0.76488474 0.17727297]]
# ------------------------------------------------
# Number of iterations: 14
# Number of samples each cluster:
#  [[118466.]
#  [ 31491.]
#  [ 50043.]]
# Centroids:
#  [[0.58875376 0.72892999 0.84322956]
#  [0.45063762 0.48560618 0.06659074]
#  [0.80559    0.76487739 0.17726529]]
# ------------------------------------------------
# Number of iterations: 15
# Number of samples each cluster:
#  [[118466.]
#  [ 31490.]
#  [ 50044.]]
# Centroids:
#  [[0.58875376 0.72892999 0.84322956]
#  [0.45063172 0.48560275 0.06658727]
#  [0.80558661 0.76487397 0.17726526]]
# ------------------------------------------------
# Number of iterations: 16
# Number of samples each cluster:
#  [[118466.]
#  [ 31490.]
#  [ 50044.]]
# Centroids:
#  [[0.58875376 0.72892999 0.84322956]
#  [0.45063172 0.48560275 0.06658727]
#  [0.80558661 0.76487397 0.17726526]]
# ------------------------------------------------
# Number of iterations: 17
# Number of samples each cluster:
#  [[118466.]
#  [ 31490.]
#  [ 50044.]]
# Centroids:
#  [[0.58875376 0.72892999 0.84322956]
#  [0.45063172 0.48560275 0.06658727]
#  [0.80558661 0.76487397 0.17726526]]
# ------------------------------------------------
# Number of iterations: 18
# Number of samples each cluster:
#  [[118466.]
#  [ 31490.]
#  [ 50044.]]
# Centroids:
#  [[0.58875376 0.72892999 0.84322956]
#  [0.45063172 0.48560275 0.06658727]
#  [0.80558661 0.76487397 0.17726526]]
# ------------------------------------------------
# Number of iterations: 19
# Number of samples each cluster:
#  [[118466.]
#  [ 31490.]
#  [ 50044.]]
# Centroids:
#  [[0.58875376 0.72892999 0.84322956]
#  [0.45063172 0.48560275 0.06658727]
#  [0.80558661 0.76487397 0.17726526]]
# ------------------------------------------------
# Number of iterations: 20
# Number of samples each cluster:
#  [[118466.]
#  [ 31490.]
#  [ 50044.]]
# Centroids:
#  [[0.58875376 0.72892999 0.84322956]
#  [0.45063172 0.48560275 0.06658727]
#  [0.80558661 0.76487397 0.17726526]]
# ------------------------------------------------
# (200000, 3)
# Number of iterations: 1
# Number of samples each cluster:
#  [[ 22403.]
#  [ 13548.]
#  [164049.]]
# Centroids:
#  [[0.71932849 0.69751403 0.69911685]
#  [0.74049773 0.73890963 0.76885368]
#  [0.36247502 0.28024987 0.07973454]]
# ------------------------------------------------
# Number of iterations: 2
# Number of samples each cluster:
#  [[ 14477.]
#  [ 23024.]
#  [162499.]]
# Centroids:
#  [[0.67943668 0.64953367 0.63129609]
#  [0.7484884  0.73939417 0.76178956]
#  [0.36025848 0.27806175 0.07680293]]
# ------------------------------------------------
# Number of iterations: 3
# Number of samples each cluster:
#  [[  9474.]
#  [ 29293.]
#  [161233.]]
# Centroids:
#  [[0.64176421 0.59105762 0.53286262]
#  [0.74068561 0.73164541 0.75367825]
#  [0.35869869 0.27649487 0.07463285]]
# ------------------------------------------------
# Number of iterations: 4
# Number of samples each cluster:
#  [[  8506.]
#  [ 32524.]
#  [158970.]]
# Centroids:
#  [[0.59545578 0.52126149 0.41414166]
#  [0.73505631 0.72608325 0.74754068]
#  [0.35628814 0.27403211 0.07122988]]
# ------------------------------------------------
# Number of iterations: 5
# Number of samples each cluster:
#  [[ 15497.]
#  [ 33449.]
#  [151054.]]
# Centroids:
#  [[0.57458159 0.47380124 0.28764749]
#  [0.73330896 0.72383453 0.74425726]
#  [0.34542814 0.26518879 0.06492235]]
# ------------------------------------------------
# Number of iterations: 6
# Number of samples each cluster:
#  [[ 39439.]
#  [ 34013.]
#  [126548.]]
# Centroids:
#  [[0.55790383 0.4407733  0.16858582]
#  [0.73219868 0.72190051 0.74098491]
#  [0.30584127 0.23448973 0.05774204]]
# ------------------------------------------------
# Number of iterations: 7
# Number of samples each cluster:
#  [[68433.]
#  [34698.]
#  [96869.]]
# Centroids:
#  [[0.5258634  0.41266982 0.12124539]
#  [0.73046618 0.71898224 0.73611387]
#  [0.25063662 0.190199   0.05492212]]
# ------------------------------------------------
# Number of iterations: 8
# Number of samples each cluster:
#  [[83781.]
#  [35275.]
#  [80944.]]
# Centroids:
#  [[0.5040646  0.3954169  0.11036442]
#  [0.72904623 0.71635244 0.73138018]
#  [0.21821138 0.16325003 0.05081585]]
# ------------------------------------------------
# Number of iterations: 9
# Number of samples each cluster:
#  [[91159.]
#  [35531.]
#  [73310.]]
# Centroids:
#  [[0.49265305 0.38652049 0.10727773]
#  [0.72831148 0.7151064  0.72922283]
#  [0.20220501 0.14961942 0.04733008]]
# ------------------------------------------------
# Number of iterations: 10
# Number of samples each cluster:
#  [[94732.]
#  [35669.]
#  [69599.]]
# Centroids:
#  [[0.48689724 0.38199641 0.10590588]
#  [0.72793144 0.71444344 0.72801914]
#  [0.19428021 0.14283394 0.04538463]]
# ------------------------------------------------
# Number of iterations: 11
# Number of samples each cluster:
#  [[96520.]
#  [35722.]
#  [67758.]]
# Centroids:
#  [[0.48402494 0.37974279 0.10527354]
#  [0.72778811 0.71418678 0.72755218]
#  [0.1903083  0.13942135 0.04440058]]
# ------------------------------------------------
# Number of iterations: 12
# Number of samples each cluster:
#  [[97349.]
#  [35753.]
#  [66898.]]
# Centroids:
#  [[0.48267653 0.37866532 0.10493194]
#  [0.72769581 0.71403546 0.72728129]
#  [0.18843102 0.13782573 0.04397155]]
# ------------------------------------------------
# Number of iterations: 13
# Number of samples each cluster:
#  [[97761.]
#  [35770.]
#  [66469.]]
# Centroids:
#  [[0.4819933  0.37813209 0.10475215]
#  [0.72764481 0.71395013 0.72713381]
#  [0.18750158 0.13701573 0.04376272]]
# ------------------------------------------------
# Number of iterations: 14
# Number of samples each cluster:
#  [[97987.]
#  [35775.]
#  [66238.]]
# Centroids:
#  [[0.48163315 0.37784402 0.10467672]
#  [0.727633   0.71392769 0.72708768]
#  [0.18699517 0.13658777 0.04363955]]
# ------------------------------------------------
# Number of iterations: 15
# Number of samples each cluster:
#  [[98096.]
#  [35782.]
#  [66122.]]
# Centroids:
#  [[0.48144289 0.37769855 0.10462609]
#  [0.72760762 0.71389127 0.72702925]
#  [0.18674823 0.13636447 0.0435733 ]]
# ------------------------------------------------
# Number of iterations: 16
# Number of samples each cluster:
#  [[98154.]
#  [35784.]
#  [66062.]]
# Centroids:
#  [[0.48134913 0.37762338 0.10459935]
#  [0.72760124 0.71388133 0.72701196]
#  [0.18661589 0.13625217 0.04354811]]
# ------------------------------------------------
# Number of iterations: 17
# Number of samples each cluster:
#  [[98185.]
#  [35785.]
#  [66030.]]
# Centroids:
#  [[0.48129885 0.37758235 0.10459021]
#  [0.72759826 0.71387678 0.72700301]
#  [0.18654571 0.13619358 0.04352753]]
# ------------------------------------------------
# Number of iterations: 18
# Number of samples each cluster:
#  [[98193.]
#  [35785.]
#  [66022.]]
# Centroids:
#  [[0.48128592 0.37757357 0.10458803]
#  [0.72759826 0.71387678 0.72700301]
#  [0.18652922 0.13617739 0.04352338]]
# ------------------------------------------------
# Number of iterations: 19
# Number of samples each cluster:
#  [[98197.]
#  [35785.]
#  [66018.]]
# Centroids:
#  [[0.48127961 0.37756899 0.10458697]
#  [0.72759826 0.71387678 0.72700301]
#  [0.18652075 0.13616959 0.04352126]]
# ------------------------------------------------
# Number of iterations: 20
# Number of samples each cluster:
#  [[98199.]
#  [35785.]
#  [66016.]]
# Centroids:
#  [[0.48127672 0.37756639 0.10458633]
#  [0.72759826 0.71387678 0.72700301]
#  [0.18651611 0.13616613 0.04352037]]
# ------------------------------------------------
# (200000, 3)
# Number of iterations: 1
# Number of samples each cluster:
#  [[77528.]
#  [94855.]
#  [27617.]]
# Centroids:
#  [[0.41585826 0.82673707 0.99106814]
#  [0.29738213 0.40720148 0.17268421]
#  [0.69990716 0.67323955 0.50506838]]
# ------------------------------------------------
# Number of iterations: 2
# Number of samples each cluster:
#  [[77823.]
#  [90582.]
#  [31595.]]
# Centroids:
#  [[0.41649215 0.82632619 0.99036881]
#  [0.2878894  0.39912595 0.16341658]
#  [0.67377467 0.65999096 0.48387064]]
# ------------------------------------------------
# Number of iterations: 3
# Number of samples each cluster:
#  [[77843.]
#  [88593.]
#  [33564.]]
# Centroids:
#  [[0.41696294 0.8265648  0.99046108]
#  [0.28344166 0.39500203 0.16042999]
#  [0.66170848 0.65476481 0.47224792]]
# ------------------------------------------------
# Number of iterations: 4
# Number of samples each cluster:
#  [[77857.]
#  [87596.]
#  [34547.]]
# Centroids:
#  [[0.41715423 0.82663884 0.99046834]
#  [0.28124965 0.39290469 0.15909722]
#  [0.65601807 0.6523497  0.46640203]]
# ------------------------------------------------
# Number of iterations: 5
# Number of samples each cluster:
#  [[77868.]
#  [87066.]
#  [35066.]]
# Centroids:
#  [[0.41724274 0.82666077 0.99045334]
#  [0.28008074 0.3918117  0.15842135]
#  [0.65313436 0.65103879 0.46330436]]
# ------------------------------------------------
# Number of iterations: 6
# Number of samples each cluster:
#  [[77872.]
#  [86804.]
#  [35324.]]
# Centroids:
#  [[0.41728008 0.82667144 0.99044891]
#  [0.2795154  0.39126718 0.15808596]
#  [0.65170104 0.65041076 0.46181728]]
# ------------------------------------------------
# Number of iterations: 7
# Number of samples each cluster:
#  [[77876.]
#  [86682.]
#  [35442.]]
# Centroids:
#  [[0.41730335 0.82667262 0.99044114]
#  [0.2792591  0.39098606 0.15794794]
#  [0.65102207 0.65018379 0.46106675]]
# ------------------------------------------------
# Number of iterations: 8
# Number of samples each cluster:
#  [[77877.]
#  [86612.]
#  [35511.]]
# Centroids:
#  [[0.41731583 0.82667709 0.99044074]
#  [0.27910326 0.39082609 0.15787902]
#  [0.65064854 0.65004826 0.46062328]]
# ------------------------------------------------
# Number of iterations: 9
# Number of samples each cluster:
#  [[77878.]
#  [86580.]
#  [35542.]]
# Centroids:
#  [[0.41732313 0.82667908 0.99043886]
#  [0.27903093 0.39075642 0.15784606]
#  [0.65048078 0.64997525 0.46042023]]
# ------------------------------------------------
# Number of iterations: 10
# Number of samples each cluster:
#  [[77878.]
#  [86563.]
#  [35559.]]
# Centroids:
#  [[0.41733028 0.82668272 0.99044079]
#  [0.27898562 0.39072217 0.1578347 ]
#  [0.65039784 0.64992672 0.460299  ]]
# ------------------------------------------------
# Number of iterations: 11
# Number of samples each cluster:
#  [[77878.]
#  [86554.]
#  [35568.]]
# Centroids:
#  [[0.41733028 0.82668272 0.99044079]
#  [0.27896656 0.39070366 0.15782298]
#  [0.65035025 0.64990618 0.46025098]]
# ------------------------------------------------
# Number of iterations: 12
# Number of samples each cluster:
#  [[77878.]
#  [86547.]
#  [35575.]]
# Centroids:
#  [[0.41733028 0.82668272 0.99044079]
#  [0.27895879 0.39069114 0.15780358]
#  [0.65029606 0.64988564 0.46023866]]
# ------------------------------------------------
# Number of iterations: 13
# Number of samples each cluster:
#  [[77878.]
#  [86546.]
#  [35576.]]
# Centroids:
#  [[0.41733028 0.82668272 0.99044079]
#  [0.27895539 0.3906906  0.15780255]
#  [0.6502939  0.64987966 0.46023266]]
# ------------------------------------------------
# Number of iterations: 14
# Number of samples each cluster:
#  [[77878.]
#  [86546.]
#  [35576.]]
# Centroids:
#  [[0.41733028 0.82668272 0.99044079]
#  [0.27895539 0.3906906  0.15780255]
#  [0.6502939  0.64987966 0.46023266]]
# ------------------------------------------------
# Number of iterations: 15
# Number of samples each cluster:
#  [[77878.]
#  [86546.]
#  [35576.]]
# Centroids:
#  [[0.41733028 0.82668272 0.99044079]
#  [0.27895539 0.3906906  0.15780255]
#  [0.6502939  0.64987966 0.46023266]]
# ------------------------------------------------
# Number of iterations: 16
# Number of samples each cluster:
#  [[77878.]
#  [86546.]
#  [35576.]]
# Centroids:
#  [[0.41733028 0.82668272 0.99044079]
#  [0.27895539 0.3906906  0.15780255]
#  [0.6502939  0.64987966 0.46023266]]
# ------------------------------------------------
# Number of iterations: 17
# Number of samples each cluster:
#  [[77878.]
#  [86546.]
#  [35576.]]
# Centroids:
#  [[0.41733028 0.82668272 0.99044079]
#  [0.27895539 0.3906906  0.15780255]
#  [0.6502939  0.64987966 0.46023266]]
# ------------------------------------------------
# Number of iterations: 18
# Number of samples each cluster:
#  [[77878.]
#  [86546.]
#  [35576.]]
# Centroids:
#  [[0.41733028 0.82668272 0.99044079]
#  [0.27895539 0.3906906  0.15780255]
#  [0.6502939  0.64987966 0.46023266]]
# ------------------------------------------------
# Number of iterations: 19
# Number of samples each cluster:
#  [[77878.]
#  [86546.]
#  [35576.]]
# Centroids:
#  [[0.41733028 0.82668272 0.99044079]
#  [0.27895539 0.3906906  0.15780255]
#  [0.6502939  0.64987966 0.46023266]]
# ------------------------------------------------
# Number of iterations: 20
# Number of samples each cluster:
#  [[77878.]
#  [86546.]
#  [35576.]]
# Centroids:
#  [[0.41733028 0.82668272 0.99044079]
#  [0.27895539 0.3906906  0.15780255]
#  [0.6502939  0.64987966 0.46023266]]
# ------------------------------------------------
# (200000, 3)
# Number of iterations: 1
# Number of samples each cluster:
#  [[ 49302.]
#  [105282.]
#  [ 45416.]]
# Centroids:
#  [[0.60228441 0.69042584 0.70178263]
#  [0.31395337 0.4514949  0.12579935]
#  [0.56388213 0.73022298 0.3591207 ]]
# ------------------------------------------------
# Number of iterations: 2
# Number of samples each cluster:
#  [[43765.]
#  [98089.]
#  [58146.]]
# Centroids:
#  [[0.64926807 0.71798249 0.7376025 ]
#  [0.29986961 0.4358832  0.12571282]
#  [0.52501648 0.69754785 0.33607303]]
# ------------------------------------------------
# Number of iterations: 3
# Number of samples each cluster:
#  [[41472.]
#  [89567.]
#  [68961.]]
# Centroids:
#  [[0.66560697 0.72760468 0.74685153]
#  [0.28618018 0.41952954 0.12040606]
#  [0.50927891 0.68134517 0.32475869]]
# ------------------------------------------------
# Number of iterations: 4
# Number of samples each cluster:
#  [[41572.]
#  [83826.]
#  [74602.]]
# Centroids:
#  [[0.66728624 0.72935663 0.7455654 ]
#  [0.27601957 0.40766657 0.11824639]
#  [0.50238191 0.67348859 0.31161032]]
# ------------------------------------------------
# Number of iterations: 5
# Number of samples each cluster:
#  [[42583.]
#  [79782.]
#  [77635.]]
# Centroids:
#  [[0.6653481  0.7297749  0.7403757 ]
#  [0.26786192 0.39854875 0.11847607]
# ...
#  [38098.]]
# Centroids:
#  [[0.14434205 0.16875075 0.20252166]
#  [0.69942974 0.79625043 0.84562795]
#  [0.28733245 0.3463186  0.40978939]]
# ------------------------------------------------
# Number of iterations: 20
# Number of samples each cluster:
#  [[65489.]
#  [95929.]
#  [38582.]]
# Centroids:
#  [[0.14369795 0.16800491 0.20165656]
#  [0.69925762 0.79609717 0.84549292]
#  [0.28608162 0.34463214 0.40785997]]
# ------------------------------------------------
# (200000, 3)
# Number of iterations: 1
# Number of samples each cluster:
#  [[ 40534.]
#  [107510.]
#  [ 51956.]]
# Centroids:
#  [[0.22204299 0.23185058 0.20016978]
#  [0.44585692 0.56149279 0.69139667]
#  [0.70903594 0.74466234 0.76871872]]
# ------------------------------------------------
# Number of iterations: 2
# Number of samples each cluster:
#  [[48731.]
#  [85887.]
#  [65382.]]
# Centroids:
#  [[0.2509376  0.26074167 0.22789513]
#  [0.43481611 0.55325392 0.69099483]
#  [0.67602012 0.73766597 0.79428983]]
# ------------------------------------------------
# Number of iterations: 3
# Number of samples each cluster:
#  [[50522.]
#  [80499.]
#  [68979.]]
# Centroids:
#  [[0.25680951 0.26669763 0.23404097]
#  [0.43167384 0.55077442 0.69066875]
#  [0.66758284 0.73417577 0.79680665]]
# ------------------------------------------------
# Number of iterations: 4
# Number of samples each cluster:
#  [[50842.]
#  [79243.]
#  [69915.]]
# Centroids:
#  [[0.25786989 0.26776716 0.23515463]
#  [0.43052095 0.55005006 0.69075828]
#  [0.66576052 0.73306391 0.79656437]]
# ------------------------------------------------
# Number of iterations: 5
# Number of samples each cluster:
#  [[50906.]
#  [78873.]
#  [70221.]]
# Centroids:
#  [[0.25807864 0.26798638 0.23537645]
#  [0.43003619 0.54978196 0.69084606]
#  [0.66528593 0.73266589 0.79625914]]
# ------------------------------------------------
# Number of iterations: 6
# Number of samples each cluster:
#  [[50920.]
#  [78732.]
#  [70348.]]
# Centroids:
#  [[0.25812859 0.26803503 0.23542297]
#  [0.42978345 0.54966421 0.69092775]
#  [0.66514216 0.73248837 0.79603438]]
# ------------------------------------------------
# Number of iterations: 7
# Number of samples each cluster:
#  [[50926.]
#  [78681.]
#  [70393.]]
# Centroids:
#  [[0.25815141 0.268057   0.23544168]
#  [0.42969039 0.54962649 0.69096118]
#  [0.66509384 0.73242177 0.79595512]]
# ------------------------------------------------
# Number of iterations: 8
# Number of samples each cluster:
#  [[50927.]
#  [78662.]
#  [70411.]]
# Centroids:
#  [[0.25815429 0.26806015 0.23544547]
#  [0.42965302 0.54960942 0.69097257]
#  [0.66507577 0.73239583 0.79591927]]
# ------------------------------------------------
# Number of iterations: 9
# Number of samples each cluster:
#  [[50927.]
#  [78660.]
#  [70413.]]
# Centroids:
#  [[0.25815429 0.26806015 0.23544547]
#  [0.42965019 0.54960691 0.69097118]
#  [0.66507224 0.73239344 0.79591785]]
# ------------------------------------------------
# Number of iterations: 10
# Number of samples each cluster:
#  [[50927.]
#  [78658.]
#  [70415.]]
# Centroids:
#  [[0.25815429 0.26806015 0.23544547]
#  [0.42964893 0.54960405 0.69096691]
#  [0.66506696 0.73239145 0.79591964]]
# ------------------------------------------------
# Number of iterations: 11
# Number of samples each cluster:
#  [[50927.]
#  [78658.]
#  [70415.]]
# Centroids:
#  [[0.25815429 0.26806015 0.23544547]
#  [0.42964893 0.54960405 0.69096691]
#  [0.66506696 0.73239145 0.79591964]]
# ------------------------------------------------
# Number of iterations: 12
# Number of samples each cluster:
#  [[50927.]
#  [78658.]
#  [70415.]]
# Centroids:
#  [[0.25815429 0.26806015 0.23544547]
#  [0.42964893 0.54960405 0.69096691]
#  [0.66506696 0.73239145 0.79591964]]
# ------------------------------------------------
# Number of iterations: 13
# Number of samples each cluster:
#  [[50927.]
#  [78658.]
#  [70415.]]
# Centroids:
#  [[0.25815429 0.26806015 0.23544547]
#  [0.42964893 0.54960405 0.69096691]
#  [0.66506696 0.73239145 0.79591964]]
# ------------------------------------------------
# Number of iterations: 14
# Number of samples each cluster:
#  [[50927.]
#  [78658.]
#  [70415.]]
# Centroids:
#  [[0.25815429 0.26806015 0.23544547]
#  [0.42964893 0.54960405 0.69096691]
#  [0.66506696 0.73239145 0.79591964]]
# ------------------------------------------------
# Number of iterations: 15
# Number of samples each cluster:
#  [[50927.]
#  [78658.]
#  [70415.]]
# Centroids:
#  [[0.25815429 0.26806015 0.23544547]
#  [0.42964893 0.54960405 0.69096691]
#  [0.66506696 0.73239145 0.79591964]]
# ------------------------------------------------
# Number of iterations: 16
# Number of samples each cluster:
#  [[50927.]
#  [78658.]
#  [70415.]]
# Centroids:
#  [[0.25815429 0.26806015 0.23544547]
#  [0.42964893 0.54960405 0.69096691]
#  [0.66506696 0.73239145 0.79591964]]
# ------------------------------------------------
# Number of iterations: 17
# Number of samples each cluster:
#  [[50927.]
#  [78658.]
#  [70415.]]
# Centroids:
#  [[0.25815429 0.26806015 0.23544547]
#  [0.42964893 0.54960405 0.69096691]
#  [0.66506696 0.73239145 0.79591964]]
# ------------------------------------------------
# Number of iterations: 18
# Number of samples each cluster:
#  [[50927.]
#  [78658.]
#  [70415.]]
# Centroids:
#  [[0.25815429 0.26806015 0.23544547]
#  [0.42964893 0.54960405 0.69096691]
#  [0.66506696 0.73239145 0.79591964]]
# ------------------------------------------------
# Number of iterations: 19
# Number of samples each cluster:
#  [[50927.]
#  [78658.]
#  [70415.]]
# Centroids:
#  [[0.25815429 0.26806015 0.23544547]
#  [0.42964893 0.54960405 0.69096691]
#  [0.66506696 0.73239145 0.79591964]]
# ------------------------------------------------
# Number of iterations: 20
# Number of samples each cluster:
#  [[50927.]
#  [78658.]
#  [70415.]]
# Centroids:
#  [[0.25815429 0.26806015 0.23544547]
#  [0.42964893 0.54960405 0.69096691]
#  [0.66506696 0.73239145 0.79591964]]
# ------------------------------------------------
# (200000, 3)
# Number of iterations: 1
# Number of samples each cluster:
#  [[72408.]
#  [39807.]
#  [87785.]]
# Centroids:
#  [[0.2204719  0.24492581 0.28870454]
#  [0.52933067 0.56564954 0.61682664]
#  [0.71678307 0.84659919 0.97140883]]
# ------------------------------------------------
# Number of iterations: 2
# Number of samples each cluster:
#  [[69289.]
#  [40722.]
#  [89989.]]
# Centroids:
#  [[0.21405407 0.23741382 0.28007512]
#  [0.50757063 0.54524146 0.59829895]
#  [0.71627548 0.84362111 0.9663804 ]]
# ------------------------------------------------
# Number of iterations: 3
# Number of samples each cluster:
#  [[66494.]
#  [42000.]
#  [91506.]]
# Centroids:
#  [[0.20819552 0.23070132 0.2724692 ]
#  [0.4912743  0.52956491 0.58360677]
#  [0.71558722 0.84134515 0.96282877]]
# ------------------------------------------------
# Number of iterations: 4
# Number of samples each cluster:
#  [[64334.]
#  [42998.]
#  [92668.]]
# Centroids:
#  [[0.2036332  0.22553137 0.26667051]
#  [0.47917728 0.5177924  0.57244136]
#  [0.71495656 0.83952105 0.9600277 ]]
# ------------------------------------------------
# Number of iterations: 5
# Number of samples each cluster:
#  [[62700.]
#  [43690.]
#  [93610.]]
# Centroids:
#  [[0.20016918 0.22166973 0.26231743]
#  [0.47002971 0.50876098 0.56381144]
#  [0.71436376 0.83798366 0.95773353]]
# ------------------------------------------------
# Number of iterations: 6
# Number of samples each cluster:
#  [[61429.]
#  [44260.]
#  [94311.]]
# Centroids:
#  [[0.19747224 0.21865964 0.25896663]
#  [0.46318859 0.50197105 0.55723401]
#  [0.713878   0.83681466 0.95601173]]
# ------------------------------------------------
# Number of iterations: 7
# Number of samples each cluster:
#  [[60483.]
#  [44622.]
#  [94895.]]
# Centroids:
#  [[0.19546457 0.21642802 0.25647847]
#  [0.4578918  0.49671664 0.55214209]
#  [0.71345662 0.83582279 0.95456441]]
# ------------------------------------------------
# Number of iterations: 8
# Number of samples each cluster:
#  [[59763.]
#  [44918.]
#  [95319.]]
# Centroids:
#  [[0.19395564 0.21473953 0.2545711 ]
#  [0.45394705 0.49280942 0.54839686]
#  [0.71314253 0.83509707 0.9535018 ]]
# ------------------------------------------------
# Number of iterations: 9
# Number of samples each cluster:
#  [[59239.]
#  [45131.]
#  [95630.]]
# Centroids:
#  [[0.19284911 0.21351006 0.25319817]
#  [0.45110652 0.48998434 0.54564242]
#  [0.71290098 0.8345551  0.95272473]]
# ------------------------------------------------
# Number of iterations: 10
# Number of samples each cluster:
#  [[58793.]
#  [45331.]
#  [95876.]]
# Centroids:
#  [[0.1919245  0.21246723 0.25201248]
#  [0.44876527 0.48765709 0.54339329]
#  [0.71270184 0.8341247  0.95211033]]
# ------------------------------------------------
# Number of iterations: 11
# Number of samples each cluster:
#  [[58469.]
#  [45494.]
#  [96037.]]
# Centroids:
#  [[0.19125315 0.21171229 0.25114989]
#  [0.44714443 0.48604089 0.54183022]
#  [0.71256941 0.8338407  0.95170772]]
# ------------------------------------------------
# Number of iterations: 12
# Number of samples each cluster:
#  [[58239.]
#  [45580.]
#  [96181.]]
# Centroids:
#  [[0.19077645 0.211179   0.25053565]
#  [0.44587086 0.48476633 0.54062736]
#  [0.71245229 0.8335909  0.95134091]]
# ------------------------------------------------
# Number of iterations: 13
# Number of samples each cluster:
#  [[58051.]
#  [45673.]
#  [96276.]]
# Centroids:
#  [[0.19037462 0.21073814 0.25005004]
#  [0.44494047 0.48382737 0.53970409]
#  [0.71237478 0.83342373 0.95109998]]
# ------------------------------------------------
# Number of iterations: 14
# Number of samples each cluster:
#  [[57889.]
#  [45768.]
#  [96343.]]
# Centroids:
#  [[0.19003011 0.21035928 0.24962857]
#  [0.44420064 0.48307671 0.53896722]
#  [0.71231921 0.83330565 0.95093013]]
# ------------------------------------------------
# Number of iterations: 15
# Number of samples each cluster:
#  [[57767.]
#  [45833.]
#  [96400.]]
# Centroids:
#  [[0.18977085 0.21007216 0.24931252]
#  [0.44361261 0.48248637 0.5383923 ]
#  [0.71227395 0.83320615 0.95078309]]
# ------------------------------------------------
# Number of iterations: 16
# Number of samples each cluster:
#  [[57681.]
#  [45875.]
#  [96444.]]
# Centroids:
#  [[0.18959349 0.20987297 0.24908192]
#  [0.44317863 0.48205029 0.53798272]
#  [0.71223752 0.83312979 0.95066991]]
# ------------------------------------------------
# Number of iterations: 17
# Number of samples each cluster:
#  [[57620.]
#  [45891.]
#  [96489.]]
# Centroids:
#  [[0.189463   0.20973021 0.24892403]
#  [0.44281837 0.48169239 0.53763295]
#  [0.71220099 0.83304946 0.95055545]]
# ------------------------------------------------
# Number of iterations: 18
# Number of samples each cluster:
#  [[57563.]
#  [45921.]
#  [96516.]]
# Centroids:
#  [[0.18934475 0.20959803 0.24877208]
#  [0.44253997 0.48141287 0.53736869]
#  [0.71217899 0.83300238 0.95048578]]
# ------------------------------------------------
# Number of iterations: 19
# Number of samples each cluster:
#  [[57530.]
#  [45934.]
#  [96536.]]
# Centroids:
#  [[0.18927542 0.20951889 0.24868734]
#  [0.44235896 0.48123859 0.53719659]
#  [0.71216402 0.83296671 0.95043393]]
# ------------------------------------------------
# Number of iterations: 20
# Number of samples each cluster:
#  [[57501.]
#  [45943.]
#  [96556.]]
# Centroids:
#  [[0.18921467 0.20945003 0.24861213]
#  [0.44219069 0.48107437 0.53703746]
#  [0.71214837 0.8329314  0.95038219]]
# ------------------------------------------------
# (200000, 3)
# Number of iterations: 1
# Number of samples each cluster:
#  [[114352.]
#  [ 39615.]
#  [ 46033.]]
# Centroids:
#  [[0.15164    0.22383652 0.27556956]
#  [0.31220757 0.43601657 0.52836088]
#  [0.47938725 0.57827662 0.65436211]]
# ------------------------------------------------
# Number of iterations: 2
# Number of samples each cluster:
#  [[95745.]
#  [62306.]
#  [41949.]]
# Centroids:
#  [[0.15105335 0.16999694 0.18621412]
#  [0.27891989 0.45369535 0.57971629]
#  [0.47522199 0.59463773 0.68216937]]
# ------------------------------------------------
# Number of iterations: 3
# Number of samples each cluster:
#  [[93073.]
#  [70881.]
#  [36046.]]
# Centroids:
#  [[0.14974149 0.16528881 0.18021218]
#  [0.27759551 0.45690874 0.58304765]
#  [0.50388216 0.60252689 0.67872464]]
# ------------------------------------------------
# Number of iterations: 4
# Number of samples each cluster:
#  [[92876.]
#  [74503.]
#  [32621.]]
# Centroids:
#  [[0.14955961 0.16495327 0.17981638]
#  [0.28065485 0.46083302 0.58678273]
#  [0.52039933 0.60804745 0.67893374]]
# ------------------------------------------------
# Number of iterations: 5
# Number of samples each cluster:
#  [[93234.]
#  [76728.]
#  [30038.]]
# Centroids:
#  [[0.14998114 0.16555243 0.18051463]
#  [0.28408452 0.46435129 0.58995025]
#  [0.53250864 0.61338629 0.68144995]]
# ------------------------------------------------
# Number of iterations: 6
# Number of samples each cluster:
#  [[93734.]
#  [78180.]
#  [28086.]]
# Centroids:
#  [[0.1506218  0.16639586 0.18147005]
#  [0.28702139 0.46728511 0.59258555]
#  [0.54184852 0.61808228 0.68457399]]
# ------------------------------------------------
# Number of iterations: 7
# Number of samples each cluster:
#  [[94170.]
#  [79747.]
#  [26083.]]
# Centroids:
#  [[0.15114914 0.16712393 0.18232056]
#  [0.29012089 0.47015092 0.59495296]
#  [0.55231715 0.62330149 0.68820138]]
# ------------------------------------------------
# Number of iterations: 8
# Number of samples each cluster:
#  [[94533.]
#  [81467.]
#  [24000.]]
# Centroids:
#  [[0.15159989 0.16773309 0.18302453]
#  [0.29344535 0.47286494 0.59698286]
#  [0.56411537 0.62956495 0.69287236]]
# ------------------------------------------------
# Number of iterations: 9
# Number of samples each cluster:
#  [[94902.]
#  [84477.]
#  [20621.]]
# Centroids:
#  [[0.15205351 0.16835702 0.18373979]
#  [0.29860618 0.47693715 0.59976828]
#  [0.58777639 0.64114834 0.70128988]]
# ------------------------------------------------
# Number of iterations: 10
# Number of samples each cluster:
#  [[95378.]
#  [87530.]
#  [17092.]]
# Centroids:
#  [[0.15263243 0.16916411 0.18466574]
#  [0.30439073 0.48099595 0.60230695]
#  [0.61870914 0.65835764 0.71566935]]
# ------------------------------------------------
# Number of iterations: 11
# Number of samples each cluster:
#  [[95826.]
#  [89459.]
#  [14715.]]
# Centroids:
#  [[0.15316522 0.16992676 0.18554226]
#  [0.30898345 0.48372984 0.60383113]
#  [0.64271237 0.67491467 0.73172247]]
# ------------------------------------------------
# Number of iterations: 12
# Number of samples each cluster:
#  [[96164.]
#  [90764.]
#  [13072.]]
# Centroids:
#  [[0.15354938 0.17050046 0.18621408]
#  [0.31243232 0.48573799 0.60500653]
#  [0.6619143  0.68889457 0.74550897]]
# ------------------------------------------------
# Number of iterations: 13
# Number of samples each cluster:
#  [[96403.]
#  [91553.]
#  [12044.]]
# Centroids:
#  [[0.15382784 0.17090632 0.18668801]
#  [0.31470261 0.48709558 0.60588783]
#  [0.67541019 0.69892183 0.75531916]]
# ------------------------------------------------
# Number of iterations: 14
# Number of samples each cluster:
#  [[96595.]
#  [91930.]
#  [11475.]]
# Centroids:
#  [[0.15405255 0.17122947 0.18707131]
#  [0.31607413 0.48795265 0.60651187]
#  [0.68310868 0.70512944 0.76151702]]
# ------------------------------------------------
# Number of iterations: 15
# Number of samples each cluster:
#  [[96717.]
#  [92147.]
#  [11136.]]
# Centroids:
#  [[0.15422357 0.17143526 0.18730403]
#  [0.31688186 0.4884919  0.60692693]
#  [0.68788783 0.70896116 0.76537512]]
# ------------------------------------------------
# Number of iterations: 16
# Number of samples each cluster:
#  [[96798.]
#  [92258.]
#  [10944.]]
# Centroids:
#  [[0.15432664 0.17157219 0.1874625 ]
#  [0.31735279 0.48881761 0.60721704]
#  [0.69071905 0.71121883 0.76741339]]
# ------------------------------------------------
# Number of iterations: 17
# Number of samples each cluster:
#  [[96849.]
#  [92308.]
#  [10843.]]
# Centroids:
#  [[0.15439293 0.171659   0.18756133]
#  [0.31760662 0.48901064 0.60737881]
#  [0.6922107  0.71236386 0.76861995]]
# ------------------------------------------------
# Number of iterations: 18
# Number of samples each cluster:
#  [[96886.]
#  [92341.]
#  [10773.]]
# Centroids:
#  [[0.15444307 0.17172086 0.18763311]
#  [0.31777992 0.48914833 0.60750095]
#  [0.69326898 0.71316853 0.76941704]]
# ------------------------------------------------
# Number of iterations: 19
# Number of samples each cluster:
#  [[96909.]
#  [92360.]
#  [10731.]]
# Centroids:
#  [[0.15447596 0.17176002 0.18767654]
#  [0.3178854  0.48922995 0.60757393]
#  [0.6938838  0.71366958 0.76993047]]
# ------------------------------------------------
# Number of iterations: 20
# Number of samples each cluster:
#  [[96925.]
#  [92365.]
#  [10710.]]
# Centroids:
#  [[0.15449347 0.17178727 0.18770883]
#  [0.31794589 0.48927886 0.60761712]
#  [0.69418508 0.71391552 0.7702114 ]]
# ------------------------------------------------

# %%
model=LogisticRegression(0.5)
model.fit(x,y,x_valid,y_valid,epoch=500,verbose=True)
# Out:
# Epoch 1 Step 1: Loss 1.203440, Acc 0.500000
# Epoch 2 Step 1: Loss 1.192945, Acc 0.500000
# Epoch 3 Step 1: Loss 1.182566, Acc 0.500000
# Epoch 4 Step 1: Loss 1.172306, Acc 0.500000
# Epoch 5 Step 1: Loss 1.162165, Acc 0.500000
# Epoch 6 Step 1: Loss 1.152145, Acc 0.500000
# Epoch 7 Step 1: Loss 1.142246, Acc 0.500000
# Epoch 8 Step 1: Loss 1.132469, Acc 0.500000
# Epoch 9 Step 1: Loss 1.122816, Acc 0.500000
# Epoch 10 Step 1: Loss 1.113288, Acc 0.500000
# Epoch 11 Step 1: Loss 1.103884, Acc 0.500000
# Epoch 12 Step 1: Loss 1.094606, Acc 0.500000
# Epoch 13 Step 1: Loss 1.085454, Acc 0.500000
# Epoch 14 Step 1: Loss 1.076430, Acc 0.500000
# Epoch 15 Step 1: Loss 1.067533, Acc 0.500000
# Epoch 16 Step 1: Loss 1.058764, Acc 0.500000
# Epoch 17 Step 1: Loss 1.050124, Acc 0.500000
# Epoch 18 Step 1: Loss 1.041613, Acc 0.500000
# Epoch 19 Step 1: Loss 1.033231, Acc 0.500000
# Epoch 20 Step 1: Loss 1.024978, Acc 0.500000
# Epoch 21 Step 1: Loss 1.016855, Acc 0.500000
# Epoch 22 Step 1: Loss 1.008862, Acc 0.500000
# Epoch 23 Step 1: Loss 1.000999, Acc 0.500000
# Epoch 24 Step 1: Loss 0.993265, Acc 0.500000
# Epoch 25 Step 1: Loss 0.985661, Acc 0.500000
# Epoch 26 Step 1: Loss 0.978187, Acc 0.500000
# Epoch 27 Step 1: Loss 0.970842, Acc 0.500000
# Epoch 28 Step 1: Loss 0.963625, Acc 0.500000
# Epoch 29 Step 1: Loss 0.956538, Acc 0.500000
# Epoch 30 Step 1: Loss 0.949578, Acc 0.500000
# Epoch 31 Step 1: Loss 0.942747, Acc 0.500000
# Epoch 32 Step 1: Loss 0.936042, Acc 0.500000
# Epoch 33 Step 1: Loss 0.929464, Acc 0.500000
# Epoch 34 Step 1: Loss 0.923011, Acc 0.500000
# Epoch 35 Step 1: Loss 0.916684, Acc 0.500000
# Epoch 36 Step 1: Loss 0.910481, Acc 0.500000
# Epoch 37 Step 1: Loss 0.904401, Acc 0.500000
# Epoch 38 Step 1: Loss 0.898444, Acc 0.500000
# Epoch 39 Step 1: Loss 0.892609, Acc 0.500000
# Epoch 40 Step 1: Loss 0.886893, Acc 0.500000
# Epoch 41 Step 1: Loss 0.881298, Acc 0.500000
# Epoch 42 Step 1: Loss 0.875820, Acc 0.500000
# Epoch 43 Step 1: Loss 0.870459, Acc 0.500000
# Epoch 44 Step 1: Loss 0.865215, Acc 0.500000
# Epoch 45 Step 1: Loss 0.860085, Acc 0.500000
# Epoch 46 Step 1: Loss 0.855068, Acc 0.500000
# Epoch 47 Step 1: Loss 0.850163, Acc 0.500000
# Epoch 48 Step 1: Loss 0.845369, Acc 0.500000
# Epoch 49 Step 1: Loss 0.840684, Acc 0.500000
# Epoch 50 Step 1: Loss 0.836106, Acc 0.500000
# Epoch 51 Step 1: Loss 0.831635, Acc 0.500000
# Epoch 52 Step 1: Loss 0.827268, Acc 0.500000
# Epoch 53 Step 1: Loss 0.823005, Acc 0.500000
# Epoch 54 Step 1: Loss 0.818843, Acc 0.500000
# Epoch 55 Step 1: Loss 0.814782, Acc 0.500000
# Epoch 56 Step 1: Loss 0.810818, Acc 0.500000
# Epoch 57 Step 1: Loss 0.806952, Acc 0.500000
# Epoch 58 Step 1: Loss 0.803181, Acc 0.500000
# Epoch 59 Step 1: Loss 0.799504, Acc 0.500000
# Epoch 60 Step 1: Loss 0.795918, Acc 0.500000
# Epoch 61 Step 1: Loss 0.792423, Acc 0.500000
# Epoch 62 Step 1: Loss 0.789017, Acc 0.500000
# Epoch 63 Step 1: Loss 0.785697, Acc 0.500000
# Epoch 64 Step 1: Loss 0.782463, Acc 0.500000
# Epoch 65 Step 1: Loss 0.779313, Acc 0.500000
# Epoch 66 Step 1: Loss 0.776245, Acc 0.500000
# Epoch 67 Step 1: Loss 0.773257, Acc 0.500000
# Epoch 68 Step 1: Loss 0.770348, Acc 0.500000
# Epoch 69 Step 1: Loss 0.767515, Acc 0.500000
# Epoch 70 Step 1: Loss 0.764759, Acc 0.500000
# Epoch 71 Step 1: Loss 0.762076, Acc 0.500000
# Epoch 72 Step 1: Loss 0.759466, Acc 0.500000
# Epoch 73 Step 1: Loss 0.756926, Acc 0.500000
# Epoch 74 Step 1: Loss 0.754455, Acc 0.500000
# Epoch 75 Step 1: Loss 0.752051, Acc 0.500000
# Epoch 76 Step 1: Loss 0.749714, Acc 0.500000
# Epoch 77 Step 1: Loss 0.747441, Acc 0.500000
# Epoch 78 Step 1: Loss 0.745230, Acc 0.500000
# Epoch 79 Step 1: Loss 0.743081, Acc 0.500000
# Epoch 80 Step 1: Loss 0.740992, Acc 0.500000
# Epoch 81 Step 1: Loss 0.738961, Acc 0.500000
# Epoch 82 Step 1: Loss 0.736988, Acc 0.500000
# Epoch 83 Step 1: Loss 0.735069, Acc 0.500000
# Epoch 84 Step 1: Loss 0.733205, Acc 0.500000
# Epoch 85 Step 1: Loss 0.731394, Acc 0.500000
# Epoch 86 Step 1: Loss 0.729633, Acc 0.500000
# Epoch 87 Step 1: Loss 0.727923, Acc 0.500000
# Epoch 88 Step 1: Loss 0.726262, Acc 0.500000
# Epoch 89 Step 1: Loss 0.724648, Acc 0.500000
# Epoch 90 Step 1: Loss 0.723080, Acc 0.500000
# Epoch 91 Step 1: Loss 0.721557, Acc 0.500000
# Epoch 92 Step 1: Loss 0.720078, Acc 0.500000
# Epoch 93 Step 1: Loss 0.718641, Acc 0.500000
# Epoch 94 Step 1: Loss 0.717245, Acc 0.500000
# Epoch 95 Step 1: Loss 0.715890, Acc 0.500000
# Epoch 96 Step 1: Loss 0.714573, Acc 0.500000
# Epoch 97 Step 1: Loss 0.713295, Acc 0.500000
# Epoch 98 Step 1: Loss 0.712054, Acc 0.500000
# Epoch 99 Step 1: Loss 0.710848, Acc 0.500000
# Epoch 100 Step 1: Loss 0.709677, Acc 0.500000
# Epoch 101 Step 1: Loss 0.708540, Acc 0.500000
# Epoch 102 Step 1: Loss 0.707435, Acc 0.500000
# Epoch 103 Step 1: Loss 0.706363, Acc 0.500000
# Epoch 104 Step 1: Loss 0.705321, Acc 0.500000
# Epoch 105 Step 1: Loss 0.704309, Acc 0.500000
# Epoch 106 Step 1: Loss 0.703326, Acc 0.500000
# Epoch 107 Step 1: Loss 0.702372, Acc 0.500000
# Epoch 108 Step 1: Loss 0.701445, Acc 0.500000
# Epoch 109 Step 1: Loss 0.700544, Acc 0.500000
# Epoch 110 Step 1: Loss 0.699669, Acc 0.500000
# Epoch 111 Step 1: Loss 0.698819, Acc 0.500000
# Epoch 112 Step 1: Loss 0.697993, Acc 0.500000
# Epoch 113 Step 1: Loss 0.697191, Acc 0.500000
# Epoch 114 Step 1: Loss 0.696411, Acc 0.500000
# Epoch 115 Step 1: Loss 0.695653, Acc 0.500000
# Epoch 116 Step 1: Loss 0.694917, Acc 0.500000
# Epoch 117 Step 1: Loss 0.694201, Acc 0.500000
# Epoch 118 Step 1: Loss 0.693505, Acc 0.500000
# Epoch 119 Step 1: Loss 0.692829, Acc 0.500000
# Epoch 120 Step 1: Loss 0.692171, Acc 0.500000
# Epoch 121 Step 1: Loss 0.691531, Acc 0.500000
# Epoch 122 Step 1: Loss 0.690909, Acc 0.500000
# Epoch 123 Step 1: Loss 0.690304, Acc 0.500000
# Epoch 124 Step 1: Loss 0.689716, Acc 0.500000
# Epoch 125 Step 1: Loss 0.689143, Acc 0.500000
# Epoch 126 Step 1: Loss 0.688585, Acc 0.500000
# Epoch 127 Step 1: Loss 0.688043, Acc 0.500000
# Epoch 128 Step 1: Loss 0.687515, Acc 0.500000
# Epoch 129 Step 1: Loss 0.687000, Acc 0.500000
# Epoch 130 Step 1: Loss 0.686500, Acc 0.500000
# Epoch 131 Step 1: Loss 0.686012, Acc 0.500000
# Epoch 132 Step 1: Loss 0.685537, Acc 0.500000
# Epoch 133 Step 1: Loss 0.685074, Acc 0.500000
# Epoch 134 Step 1: Loss 0.684622, Acc 0.500000
# Epoch 135 Step 1: Loss 0.684183, Acc 0.500000
# Epoch 136 Step 1: Loss 0.683754, Acc 0.500000
# Epoch 137 Step 1: Loss 0.683335, Acc 0.500000
# Epoch 138 Step 1: Loss 0.682927, Acc 0.500000
# Epoch 139 Step 1: Loss 0.682529, Acc 0.600000
# Epoch 140 Step 1: Loss 0.682140, Acc 0.600000
# Epoch 141 Step 1: Loss 0.681761, Acc 0.600000
# Epoch 142 Step 1: Loss 0.681390, Acc 0.600000
# Epoch 143 Step 1: Loss 0.681028, Acc 0.600000
# Epoch 144 Step 1: Loss 0.680675, Acc 0.600000
# Epoch 145 Step 1: Loss 0.680329, Acc 0.600000
# Epoch 146 Step 1: Loss 0.679991, Acc 0.700000
# Epoch 147 Step 1: Loss 0.679661, Acc 0.700000
# Epoch 148 Step 1: Loss 0.679338, Acc 0.700000
# Epoch 149 Step 1: Loss 0.679021, Acc 0.700000
# Epoch 150 Step 1: Loss 0.678712, Acc 0.700000
# Epoch 151 Step 1: Loss 0.678409, Acc 0.700000
# Epoch 152 Step 1: Loss 0.678112, Acc 0.700000
# Epoch 153 Step 1: Loss 0.677821, Acc 0.700000
# Epoch 154 Step 1: Loss 0.677536, Acc 0.700000
# Epoch 155 Step 1: Loss 0.677257, Acc 0.500000
# Epoch 156 Step 1: Loss 0.676982, Acc 0.500000
# Epoch 157 Step 1: Loss 0.676714, Acc 0.500000
# Epoch 158 Step 1: Loss 0.676450, Acc 0.500000
# Epoch 159 Step 1: Loss 0.676191, Acc 0.500000
# Epoch 160 Step 1: Loss 0.675936, Acc 0.500000
# Epoch 161 Step 1: Loss 0.675687, Acc 0.500000
# Epoch 162 Step 1: Loss 0.675441, Acc 0.500000
# Epoch 163 Step 1: Loss 0.675200, Acc 0.500000
# Epoch 164 Step 1: Loss 0.674962, Acc 0.500000
# Epoch 165 Step 1: Loss 0.674729, Acc 0.500000
# Epoch 166 Step 1: Loss 0.674499, Acc 0.500000
# Epoch 167 Step 1: Loss 0.674272, Acc 0.500000
# Epoch 168 Step 1: Loss 0.674050, Acc 0.500000
# Epoch 169 Step 1: Loss 0.673830, Acc 0.500000
# Epoch 170 Step 1: Loss 0.673614, Acc 0.500000
# Epoch 171 Step 1: Loss 0.673401, Acc 0.500000
# Epoch 172 Step 1: Loss 0.673190, Acc 0.500000
# Epoch 173 Step 1: Loss 0.672983, Acc 0.500000
# Epoch 174 Step 1: Loss 0.672778, Acc 0.500000
# Epoch 175 Step 1: Loss 0.672576, Acc 0.500000
# Epoch 176 Step 1: Loss 0.672376, Acc 0.600000
# Epoch 177 Step 1: Loss 0.672179, Acc 0.600000
# Epoch 178 Step 1: Loss 0.671984, Acc 0.600000
# Epoch 179 Step 1: Loss 0.671792, Acc 0.600000
# Epoch 180 Step 1: Loss 0.671601, Acc 0.600000
# Epoch 181 Step 1: Loss 0.671413, Acc 0.600000
# Epoch 182 Step 1: Loss 0.671226, Acc 0.600000
# Epoch 183 Step 1: Loss 0.671042, Acc 0.600000
# Epoch 184 Step 1: Loss 0.670859, Acc 0.600000
# Epoch 185 Step 1: Loss 0.670678, Acc 0.600000
# Epoch 186 Step 1: Loss 0.670499, Acc 0.600000
# Epoch 187 Step 1: Loss 0.670321, Acc 0.700000
# Epoch 188 Step 1: Loss 0.670145, Acc 0.700000
# Epoch 189 Step 1: Loss 0.669970, Acc 0.700000
# Epoch 190 Step 1: Loss 0.669797, Acc 0.700000
# Epoch 191 Step 1: Loss 0.669625, Acc 0.800000
# Epoch 192 Step 1: Loss 0.669455, Acc 0.800000
# Epoch 193 Step 1: Loss 0.669286, Acc 0.800000
# Epoch 194 Step 1: Loss 0.669118, Acc 0.800000
# Epoch 195 Step 1: Loss 0.668951, Acc 0.800000
# Epoch 196 Step 1: Loss 0.668785, Acc 0.800000
# Epoch 197 Step 1: Loss 0.668620, Acc 0.800000
# Epoch 198 Step 1: Loss 0.668456, Acc 0.800000
# Epoch 199 Step 1: Loss 0.668294, Acc 0.800000
# Epoch 200 Step 1: Loss 0.668132, Acc 0.800000
